# %%
dataset_directory = '../dataset'
test_directory = dataset_directory + '/test'

# %%
from keras.utils import image_dataset_from_directory

image_size = (256, 256)

train_dataset = image_dataset_from_directory(
    test_directory,
    label_mode = 'categorical',
    image_size = image_size,
    batch_size = 3,
    shuffle = True
)
# Out:
# Found 18 files belonging to 3 classes.

# %%
from keras.models import load_model

resnet50 = load_model('../models/res-net-50-model.keras')
vgg16 = load_model('../models/vgg-16-model.keras')
inceptionv3 = load_model('../models/inception-v3-model.keras')
mymodel = load_model('../models/my-model.keras')

# %%
from utils.evaluate_model import evaluate_model

# %% [markdown]
# ## ResNet50

# %%
evaluate_model(resnet50, train_dataset)
# Out:
# ...
# 1/1 [==============================] - 0s 40ms/step
# Covid: 0.8333
# Normal: 0.0000
# Pneumonia: 0.6667
# F1-Score: 0.3988
# Accuracy: 0.5000 | Loss: 4.9040

# %% [markdown]
# ## VGG16

# %%
evaluate_model(vgg16, train_dataset)
# Out:
# ...
# 1/1 [==============================] - 0s 32ms/step
# Covid: 1.0000
# Normal: 1.0000
# Pneumonia: 1.0000
# F1-Score: 1.0000
# Accuracy: 1.0000 | Loss: 0.1248

# %% [markdown]
# ## InceptionV3

# %%
evaluate_model(inceptionv3, train_dataset)
# Out:
# ...
# 1/1 [==============================] - 0s 44ms/step
# Covid: 1.0000
# Normal: 1.0000
# Pneumonia: 0.5000
# F1-Score: 0.8222
# Accuracy: 0.8333 | Loss: 0.4312

# %% [markdown]
# ## My Model

# %%
evaluate_model(mymodel, train_dataset)
# Out:
# ...
# 1/1 [==============================] - 0s 17ms/step
# Covid: 1.0000
# Normal: 1.0000
# Pneumonia: 1.0000
# F1-Score: 1.0000
# Accuracy: 1.0000 | Loss: 0.0676
