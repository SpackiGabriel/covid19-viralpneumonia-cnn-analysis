# %%
dataset_directory = '../dataset'
validation_directory = dataset_directory + '/validation'
train_directory = dataset_directory + '/train'

# %%
from keras.utils import image_dataset_from_directory

image_size = (256, 256)

train_dataset = image_dataset_from_directory(
    train_directory,
    label_mode = 'categorical',
    image_size = image_size,
    batch_size = 8,
    shuffle = True
)

validation_dataset = image_dataset_from_directory(
    validation_directory,
    label_mode = 'categorical',
    image_size = image_size,
    batch_size = 8,
    shuffle = True
)
# Out:
# Found 17208 files belonging to 3 classes.
# Found 1000 files belonging to 3 classes.

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
from keras.applications import ResNet50

base_model = ResNet50 (
    weights = 'imagenet',
    include_top = False,
    input_shape = image_size + (3,)
)

base_model.trainable = False

# %%
from keras.models import Sequential
from keras.layers import InputLayer, Rescaling, RandomFlip, RandomRotation, GlobalAveragePooling2D, Flatten, BatchNormalization, Dropout, Dense

model = Sequential (
    [
        InputLayer(input_shape = image_size + (3,)),

        Rescaling(1./255),
        RandomFlip('horizontal_and_vertical'),
        RandomRotation(factor=0.4, fill_mode='wrap'),

        base_model,

        GlobalAveragePooling2D(),
        Flatten(),

        Dense(64, activation='elu', kernel_initializer='he_normal'),
        BatchNormalization(),
        Dropout(0.2),

        Dense(64, activation='elu', kernel_initializer='he_normal'),
        BatchNormalization(),
        Dropout(0.2),

        Dense(3, activation='softmax')
    ]
)

# %%
from keras.optimizers import Adam

model.compile (
    optimizer = Adam(),
    loss='categorical_crossentropy',
    metrics=['categorical_accuracy']
)

# %%
from keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint(
    filepath = '../models/res-net-50-model.keras',
    monitor ='val_categorical_accuracy',
    verbose = True,
    save_best_only = True,
    save_weights_only=False,
    mode = 'max'
)

# %%
history = model.fit(
    train_dataset,
    epochs = 5,
    validation_data = validation_dataset,
    callbacks = [checkpoint]
)
# Out:
# Epoch 1/5
# 2151/2151 [==============================] - ETA: 0s - loss: 0.5548 - categorical_accuracy: 0.7750
# Epoch 1: val_categorical_accuracy improved from -inf to 0.55900, saving model to ../models\res-net-50-model.keras
# 2151/2151 [==============================] - 261s 117ms/step - loss: 0.5548 - categorical_accuracy: 0.7750 - val_loss: 1.9013 - val_categorical_accuracy: 0.5590
# Epoch 2/5
# 2151/2151 [==============================] - ETA: 0s - loss: 0.4457 - categorical_accuracy: 0.8207
# Epoch 2: val_categorical_accuracy did not improve from 0.55900
# 2151/2151 [==============================] - 257s 119ms/step - loss: 0.4457 - categorical_accuracy: 0.8207 - val_loss: 7.4105 - val_categorical_accuracy: 0.3340
# Epoch 3/5
# 2151/2151 [==============================] - ETA: 0s - loss: 0.4286 - categorical_accuracy: 0.8308
# Epoch 3: val_categorical_accuracy did not improve from 0.55900
# 2151/2151 [==============================] - 243s 113ms/step - loss: 0.4286 - categorical_accuracy: 0.8308 - val_loss: 1.7276 - val_categorical_accuracy: 0.5230
# Epoch 4/5
# 2151/2151 [==============================] - ETA: 0s - loss: 0.4117 - categorical_accuracy: 0.8391
# Epoch 4: val_categorical_accuracy did not improve from 0.55900
# 2151/2151 [==============================] - 250s 116ms/step - loss: 0.4117 - categorical_accuracy: 0.8391 - val_loss: 5.1637 - val_categorical_accuracy: 0.3410
# Epoch 5/5
# 2151/2151 [==============================] - ETA: 0s - loss: 0.4052 - categorical_accuracy: 0.8436
# Epoch 5: val_categorical_accuracy did not improve from 0.55900
# 2151/2151 [==============================] - 257s 119ms/step - loss: 0.4052 - categorical_accuracy: 0.8436 - val_loss: 3.5728 - val_categorical_accuracy: 0.3340

# %%
from keras.models import load_model

model = load_model('../models/res-net-50-model.keras')

# %%
start_tunning_at = len(base_model.layers) - int(0.3 * len(base_model.layers))

print(f"Number of layers in the base model: {len(base_model.layers)}")
print(f"Number of layers to be fine-tuned: {len(base_model.layers) - start_tunning_at}")
# Out:
# Number of layers in the base model: 175
# Number of layers to be fine-tuned: 52

# %%
for layer in base_model.layers[start_tunning_at:]:
    layer.trainable = True

# %%
from keras.optimizers import Adam

model.compile (
    optimizer = Adam(),
    loss = 'categorical_crossentropy',
    metrics = ['categorical_accuracy']
)

# %%
history = model.fit (
    train_dataset,
    epochs = 30,
    validation_data = validation_dataset,
    callbacks = [checkpoint]
)
# Out:
# Epoch 1/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.4653 - categorical_accuracy: 0.8162
# Epoch 1: val_categorical_accuracy did not improve from 0.55900
# 2151/2151 [==============================] - 266s 120ms/step - loss: 0.4653 - categorical_accuracy: 0.8162 - val_loss: 1.6671 - val_categorical_accuracy: 0.5490
# Epoch 2/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.4227 - categorical_accuracy: 0.8334
# Epoch 2: val_categorical_accuracy did not improve from 0.55900
# 2151/2151 [==============================] - 251s 116ms/step - loss: 0.4227 - categorical_accuracy: 0.8334 - val_loss: 10.5433 - val_categorical_accuracy: 0.3340
# Epoch 3/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.4147 - categorical_accuracy: 0.8387
# Epoch 3: val_categorical_accuracy did not improve from 0.55900
# 2151/2151 [==============================] - 252s 117ms/step - loss: 0.4147 - categorical_accuracy: 0.8387 - val_loss: 3.6903 - val_categorical_accuracy: 0.3370
# Epoch 4/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3991 - categorical_accuracy: 0.8458
# Epoch 4: val_categorical_accuracy did not improve from 0.55900
# 2151/2151 [==============================] - 252s 117ms/step - loss: 0.3991 - categorical_accuracy: 0.8458 - val_loss: 2.7212 - val_categorical_accuracy: 0.3390
# Epoch 5/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3910 - categorical_accuracy: 0.8467
# Epoch 5: val_categorical_accuracy did not improve from 0.55900
# 2151/2151 [==============================] - 252s 117ms/step - loss: 0.3910 - categorical_accuracy: 0.8467 - val_loss: 1.9427 - val_categorical_accuracy: 0.3560
# Epoch 6/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3858 - categorical_accuracy: 0.8512
# Epoch 6: val_categorical_accuracy did not improve from 0.55900
# 2151/2151 [==============================] - 256s 119ms/step - loss: 0.3858 - categorical_accuracy: 0.8512 - val_loss: 6.7366 - val_categorical_accuracy: 0.3340
# Epoch 7/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3867 - categorical_accuracy: 0.8523
# Epoch 7: val_categorical_accuracy improved from 0.55900 to 0.56800, saving model to ../models\res-net-50-model.keras
# 2151/2151 [==============================] - 254s 118ms/step - loss: 0.3867 - categorical_accuracy: 0.8523 - val_loss: 3.0491 - val_categorical_accuracy: 0.5680
# Epoch 8/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3801 - categorical_accuracy: 0.8544
# Epoch 8: val_categorical_accuracy did not improve from 0.56800
# 2151/2151 [==============================] - 247s 115ms/step - loss: 0.3801 - categorical_accuracy: 0.8544 - val_loss: 6.4563 - val_categorical_accuracy: 0.3360
# Epoch 9/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3690 - categorical_accuracy: 0.8584
# Epoch 9: val_categorical_accuracy improved from 0.56800 to 0.62100, saving model to ../models\res-net-50-model.keras
# 2151/2151 [==============================] - 254s 118ms/step - loss: 0.3690 - categorical_accuracy: 0.8584 - val_loss: 4.3161 - val_categorical_accuracy: 0.6210
# Epoch 10/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3622 - categorical_accuracy: 0.8629
# Epoch 10: val_categorical_accuracy did not improve from 0.62100
# 2151/2151 [==============================] - 248s 115ms/step - loss: 0.3622 - categorical_accuracy: 0.8629 - val_loss: 3.8865 - val_categorical_accuracy: 0.3450
# Epoch 11/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3640 - categorical_accuracy: 0.8623
# Epoch 11: val_categorical_accuracy did not improve from 0.62100
# 2151/2151 [==============================] - 258s 120ms/step - loss: 0.3640 - categorical_accuracy: 0.8623 - val_loss: 1.4654 - val_categorical_accuracy: 0.4190
# Epoch 12/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3627 - categorical_accuracy: 0.8612
# Epoch 12: val_categorical_accuracy did not improve from 0.62100
# 2151/2151 [==============================] - 250s 116ms/step - loss: 0.3627 - categorical_accuracy: 0.8612 - val_loss: 7.0912 - val_categorical_accuracy: 0.3370
# Epoch 13/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3647 - categorical_accuracy: 0.8640
# Epoch 13: val_categorical_accuracy did not improve from 0.62100
# 2151/2151 [==============================] - 253s 118ms/step - loss: 0.3647 - categorical_accuracy: 0.8640 - val_loss: 1.9747 - val_categorical_accuracy: 0.5030
# Epoch 14/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3615 - categorical_accuracy: 0.8640
# Epoch 14: val_categorical_accuracy did not improve from 0.62100
# 2151/2151 [==============================] - 256s 119ms/step - loss: 0.3615 - categorical_accuracy: 0.8640 - val_loss: 1.6773 - val_categorical_accuracy: 0.4750
# Epoch 15/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3609 - categorical_accuracy: 0.8638
# Epoch 15: val_categorical_accuracy did not improve from 0.62100
# 2151/2151 [==============================] - 255s 119ms/step - loss: 0.3609 - categorical_accuracy: 0.8638 - val_loss: 1.7094 - val_categorical_accuracy: 0.5320
# Epoch 16/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3555 - categorical_accuracy: 0.8663
# Epoch 16: val_categorical_accuracy did not improve from 0.62100
# 2151/2151 [==============================] - 254s 118ms/step - loss: 0.3555 - categorical_accuracy: 0.8663 - val_loss: 6.9713 - val_categorical_accuracy: 0.4290
# Epoch 17/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3571 - categorical_accuracy: 0.8684
# Epoch 17: val_categorical_accuracy improved from 0.62100 to 0.72600, saving model to ../models\res-net-50-model.keras
# 2151/2151 [==============================] - 257s 119ms/step - loss: 0.3571 - categorical_accuracy: 0.8684 - val_loss: 1.1465 - val_categorical_accuracy: 0.7260
# Epoch 18/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3516 - categorical_accuracy: 0.8649
# Epoch 18: val_categorical_accuracy did not improve from 0.72600
# 2151/2151 [==============================] - 257s 120ms/step - loss: 0.3516 - categorical_accuracy: 0.8649 - val_loss: 5.5535 - val_categorical_accuracy: 0.3380
# Epoch 19/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3437 - categorical_accuracy: 0.8698
# Epoch 19: val_categorical_accuracy did not improve from 0.72600
# 2151/2151 [==============================] - 259s 120ms/step - loss: 0.3437 - categorical_accuracy: 0.8698 - val_loss: 7.2915 - val_categorical_accuracy: 0.3340
# Epoch 20/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3513 - categorical_accuracy: 0.8697
# Epoch 20: val_categorical_accuracy did not improve from 0.72600
# 2151/2151 [==============================] - 259s 120ms/step - loss: 0.3513 - categorical_accuracy: 0.8697 - val_loss: 1.7174 - val_categorical_accuracy: 0.4420
# Epoch 21/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3362 - categorical_accuracy: 0.8723
# Epoch 21: val_categorical_accuracy did not improve from 0.72600
# 2151/2151 [==============================] - 260s 121ms/step - loss: 0.3362 - categorical_accuracy: 0.8723 - val_loss: 4.9613 - val_categorical_accuracy: 0.3410
# Epoch 22/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3450 - categorical_accuracy: 0.8714
# Epoch 22: val_categorical_accuracy did not improve from 0.72600
# 2151/2151 [==============================] - 257s 119ms/step - loss: 0.3450 - categorical_accuracy: 0.8714 - val_loss: 2.7982 - val_categorical_accuracy: 0.5740
# Epoch 23/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3414 - categorical_accuracy: 0.8706
# Epoch 23: val_categorical_accuracy did not improve from 0.72600
# 2151/2151 [==============================] - 260s 121ms/step - loss: 0.3414 - categorical_accuracy: 0.8706 - val_loss: 8.2982 - val_categorical_accuracy: 0.3340
# Epoch 24/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3380 - categorical_accuracy: 0.8726
# Epoch 24: val_categorical_accuracy did not improve from 0.72600
# 2151/2151 [==============================] - 255s 119ms/step - loss: 0.3380 - categorical_accuracy: 0.8726 - val_loss: 3.4207 - val_categorical_accuracy: 0.4770
# Epoch 25/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3414 - categorical_accuracy: 0.8716
# Epoch 25: val_categorical_accuracy did not improve from 0.72600
# 2151/2151 [==============================] - 254s 118ms/step - loss: 0.3414 - categorical_accuracy: 0.8716 - val_loss: 3.9425 - val_categorical_accuracy: 0.3870
# Epoch 26/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3358 - categorical_accuracy: 0.8722
# Epoch 26: val_categorical_accuracy did not improve from 0.72600
# 2151/2151 [==============================] - 252s 117ms/step - loss: 0.3358 - categorical_accuracy: 0.8722 - val_loss: 1.6823 - val_categorical_accuracy: 0.5180
# Epoch 27/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3329 - categorical_accuracy: 0.8751
# Epoch 27: val_categorical_accuracy did not improve from 0.72600
# 2151/2151 [==============================] - 249s 116ms/step - loss: 0.3329 - categorical_accuracy: 0.8751 - val_loss: 2.6271 - val_categorical_accuracy: 0.6140
# Epoch 28/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3407 - categorical_accuracy: 0.8746
# Epoch 28: val_categorical_accuracy did not improve from 0.72600
# 2151/2151 [==============================] - 240s 111ms/step - loss: 0.3407 - categorical_accuracy: 0.8746 - val_loss: 3.7602 - val_categorical_accuracy: 0.3930
# Epoch 29/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3368 - categorical_accuracy: 0.8731
# Epoch 29: val_categorical_accuracy did not improve from 0.72600
# 2151/2151 [==============================] - 249s 116ms/step - loss: 0.3368 - categorical_accuracy: 0.8731 - val_loss: 4.0300 - val_categorical_accuracy: 0.4130
# Epoch 30/30
# 2151/2151 [==============================] - ETA: 0s - loss: 0.3276 - categorical_accuracy: 0.8788
# Epoch 30: val_categorical_accuracy did not improve from 0.72600
# 2151/2151 [==============================] - 243s 113ms/step - loss: 0.3276 - categorical_accuracy: 0.8788 - val_loss: 3.5039 - val_categorical_accuracy: 0.5420

# %%
from utils.plot_history import plot_history
plot_history(history)

# %%
from keras.models import load_model
model = load_model('../models/res-net-50-model.keras')

# %%
from utils.evaluate_model import evaluate_model 
evaluate_model(model, validation_dataset)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# Covid: 0.9701
# Normal: 0.3003
# Pneumonia: 0.9069
# F1-Score: 0.6865
# Accuracy: 0.7260 | Loss: 1.1465
